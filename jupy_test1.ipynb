# %%
import torch

# %%
x=torch.rand(2,3)

# %%
print(x)
# Out:
# tensor([[0.8426, 0.5506, 0.4485],
#         [0.5651, 0.7326, 0.3466]])

# %%
import torch

# %%
x=torch.rand(34,56)

# %%
print(x)
# Out:
# tensor([[0.2756, 0.6084, 0.2066,  ..., 0.6719, 0.7375, 0.4848],
#         [0.6464, 0.1495, 0.8406,  ..., 0.7103, 0.3849, 0.8652],
#         [0.1354, 0.3087, 0.3018,  ..., 0.0560, 0.1264, 0.6556],
#         ...,
#         [0.7596, 0.9009, 0.7226,  ..., 0.5395, 0.7987, 0.5774],
#         [0.8273, 0.7569, 0.8062,  ..., 0.2629, 0.2413, 0.1761],
#         [0.4759, 0.5547, 0.4737,  ..., 0.3645, 0.5932, 0.0996]])
